# %%
import pandas as pd
crime_data = pd.read_csv('C:/Users/622857/Downloads/Crimes_-_2001_to_Present.csv')

# %%
crime_data.isnull().sum()
# Out:
# ID                           0
# Case Number                  4
# Date                         0
# Block                        0
# IUCR                         0
# Primary Type                 0
# Description                  0
# Location Description      9142
# Arrest                       0
# Domestic                     0
# Beat                         0
# District                    47
# Ward                    614843
# Community Area          613478
# FBI Code                     0
# X Coordinate             78646
# Y Coordinate             78646
# Year                         0
# Updated On                   0
# Latitude                 78646
# Longitude                78646
# Location                 78646
# dtype: int64

# %%
crime_data.loc[:,'Date'].str.len().value_counts()
#all dates are in the same format
# Out:
# 22    7520239
# Name: Date, dtype: int64

# %%
crime_data.rename(columns={'Date':'Original_Date'}, inplace=True)
crime_data['Date'] = [date[0] for date in crime_data['Original_Date'].str.split(' ')]
crime_data['Timestamp'] = [timestamp[1] for timestamp in crime_data['Original_Date'].str.split(' ')]

# %%
crime_data.head()
# Out:
#          ID Case Number           Original_Date                  Block  IUCR  \
# 0  10224738    HY411648  09/05/2015 01:30:00 PM        043XX S WOOD ST  0486
# 1  10224739    HY411615  09/04/2015 11:30:00 AM    008XX N CENTRAL AVE  0870
# 2  11646166    JC213529  09/01/2018 12:01:00 AM  082XX S INGLESIDE AVE  0810
# 3  10224740    HY411595  09/05/2015 12:45:00 PM      035XX W BARRY AVE  2023
# 4  10224741    HY411610  09/05/2015 01:00:00 PM    0000X N LARAMIE AVE  0560
#
#   Primary Type              Description Location Description  Arrest  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE   False
# 1        THEFT           POCKET-PICKING              CTA BUS   False
# 2        THEFT                OVER $500            RESIDENCE   False
# 3    NARCOTICS    POSS: HEROIN(BRN/TAN)             SIDEWALK    True
# 4      ASSAULT                   SIMPLE            APARTMENT   False
#
#    Domestic  ...  FBI Code  X Coordinate  Y Coordinate  Year  \
# ...
